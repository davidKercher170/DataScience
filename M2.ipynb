# %% [markdown]
# #### 2 A Stable Limit Cycle
#
# ##### 1 Verify that (0,0) is an equilibrium point, and linearize the system (1) around it. Prove how the stability of this equilibrium point changes as a function of the parameter $\mu$.
#
# $$\frac{dx_1}{dt} = 0(\mu - 0 - 0) - 0 = 0$$
# $$\frac{dx_2}{dt} = 0(\mu - 0 - 0) - 0 = 0$$
#
#
# Linearization: $\frac{df_1}{dx_1} = \mu - 3x_1^2 - x^2_2$, $\frac{df_1}{dx_2} = -2x_1x_2-1$, $\frac{df_2}{dx_1} = -2x_1x_2+1$, $\frac{df_2}{dx_2} = \mu - 3x_1^2 - x_1^2$.
#
# Then for the point (0,0): $f'(x_1,x_2) \approx  \begin{bmatrix}
# \mu & -1\\
# 1 & \mu
# \end{bmatrix}\begin{bmatrix}
# x_1 \\
# x_2
# \end{bmatrix}$.
#
# Then our eigenvalues for the system are calculated:
#
# $$\mathrm{det}(A-\lambda I) = (\mu-\lambda)(\mu-\lambda) + 1 = 0$$
# $$\implies \mu^2 + \lambda^2 - 2\lambda \mu = -1$$
# $$\implies \lambda^2-2\lambda \mu = -\mu^2-1$$
#
# or alternatively:
#
# $$\mathrm{det}(A-\lambda I) = (\mu-\lambda)(\mu-\lambda) +1 = 0$$
# $$\implies (\mu-\lambda)(\mu-\lambda) = -1$$
# $$\implies |(\mu-\lambda)^2| = |-1|$$
# $$\implies |(\mu-\lambda)| = 1$$
#
# So as the value of $\mu$ changes so do the eigenvalues of the matrix A. The eigenvalues could be less than or greater than 0, resulting in either stable, marginally stable, or unstable equilibrium.
#
# ##### 2 Equation (1) describes a “bucket of models” where each model “in the bucket” is characterized by a different value of µ. Some models in the bucket, however, behave qualitatively differently than others, as demonstrated, for example, by different stability properties of the equilibrium at the origin. How many distinct types of qualitative behaviors do models in this “bucket” exhibit, and what are the values of µ that characterize each group of models?
#
# There are two seperate bucket of models distinguished by the stability classification (whether it is unstable or stable). We know that stability changes at the crictical values |$\lambda| = 1$.
#
# Thus if we examine $|(\mu-\lambda)| = 1$, then the critical values of $\mu$ are $\mu = 2$ and $\mu = -2$.
#
#
# ##### 3 Plot a phase portrait for each group of models with a distinct type of qualitative behavior as found in Part B.
#
# Didn't have time to complete.
#
#
# ##### 4 Verify that when $\mu = 4$ the system (1) exhibits a limit cycle by 1) plotting a phase portrait, and 2) verifying that $x_1(t)=2cos(t), x_2(t) = 2sin(t)$ satisfy the equation (1).
#
# If we plug $x_1(t)=2cos(t), x_2(t) = 2sin(t)$ and $\mu=4$ into our system of equations, we get:
#
# $$\frac{dx_1}{dt} = 2cos(t)(\mu - 4cos^2(t) - 4sin^2(t)) - 2sin(t)$$
# $$\frac{dx_2}{dt} = 2sin(t)(\mu - 4cos^2(t) - 4sin^2(t)) + 2cos(t)$$
#
# which simplified gives us:
#
# $$\frac{dx_1}{dt} = 2cos(t)(4 - 4) - 2sin(t) = - 2sin(t)$$
# $$\frac{dx_2}{dt} = 2sin(t)(4 - 4) + 2cos(t) = 2cos(t)$$
#
# Similarly if we directly differentiate our terms:
#
# $$\frac{dx_1}{dt} = \frac{d}{dt}2cos(t) = - 2sin(t)$$
# $$\frac{dx_2}{dt} = \frac{d}{dt}2sin(t) = 2cos(t)$$
#
# yielding the same results as desired.
#
#
# ##### 5 Prove that this limit cycle is stable by 1) representing the dynamics in (1) in polar coordinates with the transformation $x_1 = r cos \theta, x_2 = r sin \theta$, yielding equations for r˙ and ˙θ, 2) demonstrating the values of r that put the r˙ equation in equilibrium, 3) linearizing the equation for r˙ around the equilibrium corresponding to the limit cycle and showing that the resulting linear system is stable, thus proving that the limit cycle is stable.
#
# Let $x_1 = r cos \theta, x_2 = r sin \theta$, then we can find r' as follows:
#
# $$r = \sqrt{x_1^2 + x_2^2} \implies r^2 = x_1^2 + x_2^2 \implies r' = \frac{x_1x_1' + x_2x_2'}{r}$$
#
# $$ \implies r' = cos(\theta)[rcos(\theta)(\mu-r^2) - rsin(\theta)] + sin(\theta)[rsin(\theta)(\mu-r^2)+rcos(\theta)]$$
#
# $$ = rcos^2(\theta)(\mu-r^2) + rsin^2(\theta)(\mu-r^2)$$
#
# $$ = r( \mu-r^2)$$
#
# Then to find theta:
#
# $$tan(\theta) = \frac{x_2}{x_1} \implies \theta'=\frac{x_2'x_1 - x_1'x_2}{r^2}$$
#
# $$\implies \theta' = cos(\theta)sin(\theta)(\mu-r^2) + sin(\theta)cos(\theta)(\mu-r^2)$$
#
# $$ = 2sin(\theta)cos(\theta)(\mu-r^2)$$
#
#
# Thus,
#
# $$ \frac{dr}{dt}= r( \mu-r^2)$$
# $$ \frac{d\theta}{dt}= 2sin(\theta)cos(\theta)(\mu-r^2)$$
#
# Then the system is in equilibrium for $r^2 = \mu$ or $r = \pm \sqrt{\mu}$ as well as the equilibrium value $r=0$.
#
# Linearizing the r equation: Let $f(x) = r( \mu-r^2)$ then $\frac{df}{dr} = \mu - 3r^2$. If we take $\mu =4$ (which I assume it means that we should, this is the value from 4), we get:
#
# $$\frac{dr}{dt}(2) \approx 4 - 3(2)^2 = -8$$
# $$\frac{dr}{dt}(0) \approx 4 - 3(0)^2 = 4$$
#
# Thus the limit cycle corresponding to $r=2$ is stable since it the linearization is less than 0.

# %% [markdown]
# #### 3 Sufficiency Conditions for Network Reconstruction
#
# ##### Consider a $m × m$ transfer function G(s) that is full rank for most values of $s \in C$. Suppose that you have already learned this transfer function from input-output data, but you are interested in knowing more structural detail about your system. As a result, suppose that you consider deriving its “true” dynamical structure function, which satisfies the relation:
#
# $$ G(s) = (I - Q(s))^{-1}P(s).$$
#
#
# Unfortunately didn't have time to work through this problem.

# %% [markdown]
# ### 4 Bifurcations in a Resource-Use Model
#
#
# ##### 1. Equilibrium Points: $(3,3)$, $(-2,-2)$
#
# ##### 2. Linearization: $\frac{df_1}{dx_1} = x_2+2$, $\frac{df_1}{dx_2} = x_1-3$, $\frac{df_2}{dx_1} = x_1-3$, $\frac{df_2}{dx_2} = x_2+2$.
#
# Then in general: $f'(x_1,x_2) \approx  \begin{bmatrix}
# x_2+2 & x_1-3\\
# x_2-3 & x_1+2
# \end{bmatrix}\begin{bmatrix}
# x_1 \\
# x_2
# \end{bmatrix}$.
#
# For the point (3,3): $f'(x_1,x_2) \approx  \begin{bmatrix}
# 5 & 0\\
# 0 & 5
# \end{bmatrix}\begin{bmatrix}
# x_1 \\
# x_2
# \end{bmatrix}$.
#
# The eigenvalues for this system are $\lambda = 5, 5$.
#
# For the point (-2,-2): $f'(x_1,x_2) \approx \begin{bmatrix}
# 0 & -5\\
# -5 & 0
# \end{bmatrix}\begin{bmatrix}
# x_1 \\
# x_2
# \end{bmatrix}$.
#
# The eigenvalues for this system are $\lambda = 5, -5$.
#
#
# ##### 3. Can you determine the stability properties of each equilibrium point by analyzing the linearized system at that point? If so, what are the stability properties for each point? If not, why not?
#
# We can determine the stability properties for these linearized systems:
#
# For the first point (3,3), the point would be unstable since both eigenvalues are greater than 0.
#
# For the second point (-2,2), the point would also be unstable since it has one eigenvalue greater than 0.

# %% [markdown]
# #### 5 Bifurcations in a Resource-Use Model
#
# ##### 1. Find the equilibrium points of this equation. Take p to be the bifurcation parameter and sketch the bifurcation diagram x vs. p. At what critical value of $p = p^∗$ does the bifurcation occur?
#
# Equilibrium Points: $x = 0$ and $x = L(1-\frac{p}{r})$.
#
# The critical value is $p = p^* = r$, where there the stability at $x=0$ and $x = L(1-\frac{p}{r})$ switch. $x=0$ becomes stable for $p>r$ and $x = L(1-\frac{p}{r})$ becomes unstable. While for $p<r$ $x=0$ is unstable while $x = L(1-\frac{p}{r})$ is unstable.
#
# Note: The sketch is included in the box below.
#
# ##### 2. The Linearization of the system is given by:
#
# $$f(x) = rx - \frac{rx^2}{L} - px$$
# $$ \implies f'(x) = r- \frac{2rx}{L}-p$$
#
# Thus evaluating at our stable equilibrium (for p < r):
#
# $$f'(L(1-\frac{p}{r})) = r - 2r (1-\frac{p}{r}) - p = p - r $$
#
# Then taking the limit:
#
# $$\mathrm{lim_{p \to r}}f'(L(1-\frac{p}{r})) = \mathrm{lim_{p \to r}} p - r = 0$$
#
# Thus it will take infinitely long to approach the stable equilibrium.
